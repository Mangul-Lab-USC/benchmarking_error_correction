# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %%
data = pd.read_csv('../summary_data/ecoli_summary.csv')
print(data.columns)
data["Trim Effeciency"] = data["Base - TP TRIM"]/(data["Base - TP TRIM"] + data["Base - FP TRIM"])
data['total_corrections']=data['Base - TP']+ data['Base - FP']
data.head()
# Out:
# Index(['Unnamed: 0', 'EC Filename', 'Wrapper Name', 'Kmer Size', 'Read - TP',
#        'Read - TN', 'Read - FN', 'Read - FN WRONG', 'Read - FP',
#        'Read - FP INDEL', 'Total Trimmed Reads', 'Total Reads', 'Base - TP',
#        'Base - TN', 'Base - FN', 'Base - FN WRONG', 'Base - FP',
#        'Base - FP INDEL', 'Base - FP TRIM', 'Base - TP TRIM', 'Total Bases',
#        'Tool', 'Coverage', 'Length', 'Base Sensitivity', 'Base Precision',
#        'Base Gain', 'Base Accuracy', 'Dataset', 'Trim Percent',
#        'Trim Effeciency'],
#       dtype='object')
#    Unnamed: 0                                EC Filename Wrapper Name  \
# 0           0  bfc_wgsim_rl_100_cov_1_20.corrected.fastq          bfc
# 1           1  bfc_wgsim_rl_100_cov_1_22.corrected.fastq          bfc
# 2           2  bfc_wgsim_rl_100_cov_1_24.corrected.fastq          bfc
# 3           3  bfc_wgsim_rl_100_cov_1_26.corrected.fastq          bfc
# ...

# %% [markdown]
# # CHANGE KMER VALUE HERE

# %%
KMER=30

data = data[(data['Kmer Size'] == KMER)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] == 1)]);
g.set(xlabel='Total number of corrections', ylabel='Methods', title='Kmer '+str(KMER)+' Coverage 1')
g.fig.tight_layout()
g=sns.despine()
plt.savefig("../figures/ecoli_total_corrections_vs_tool_cov1_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] == 2)]);
g.set(xlabel='Total number of corrections', ylabel='Methods', title='Kmer '+str(KMER)+' Coverage 2')
g.fig.tight_layout()
g=sns.despine()
plt.savefig("../figures/ecoli_total_corrections_vs_tool_cov2_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] == 4)]);
g.set(xlabel='Total number of corrections', ylabel='Methods', title='Kmer '+str(KMER)+' Coverage 4')
g.fig.tight_layout()
g=sns.despine()
plt.savefig("../figures/ecoli_total_corrections_vs_tool_cov4_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] == 8)]);
g.set(xlabel='Total number of corrections', ylabel='Methods', title='Kmer '+str(KMER)+' Coverage 8')
g.fig.tight_layout()
g=sns.despine()
plt.savefig("../figures/ecoli_total_corrections_vs_tool_cov8_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] == 16)]);
g.set(xlabel='Total number of corrections', ylabel='Methods', title='Kmer '+str(KMER)+' Coverage 16')
g.fig.tight_layout()
g=sns.despine()
plt.savefig("../figures/ecoli_total_corrections_vs_tool_cov16_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] == 32)]);
g.set(xlabel='Total number of corrections', ylabel='Methods', title='Kmer '+str(KMER)+' Coverage 32')
g.fig.tight_layout()
g=sns.despine()
plt.savefig("../figures/ecoli_total_corrections_vs_tool_cov32_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="total_corrections", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='Total corrections', title='Kmer '+str(KMER))
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/ecoli_total_corrections_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - TP", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='TP',  title='Kmer '+str(KMER))
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/ecoli_TP_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - FP", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='FP', title='Kmer '+str(KMER))
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/ecoli_FP_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - FN", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='FN',title='Kmer '+str(KMER))
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/ecoli_FN_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base Gain", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='Gain',  title='Kmer '+str(KMER))
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/ecoli_gain_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
result = data.pivot(index='Tool', columns='Coverage', values='Base Gain')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result, fmt="g", cmap='gist_ncar',center=0,linewidths=.5)
g.set(xlabel='Coverage', ylabel='Tool',  title='Gain - Kmer '+str(KMER))
plt.savefig("../figures/ecoli_heatmap_gain_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
result_PPV = data.pivot(index='Tool', columns='Coverage', values='Base Precision')

import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result_PPV, fmt="g", cmap='gist_ncar',center=0,linewidths=.5)
g.set(xlabel='Coverage', ylabel='Tool',  title='Base Precision - Kmer '+str(KMER))

plt.savefig("../figures/ecoli_heatmap_ppv_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')

# %%
result_Sensitivity = data.pivot(index='Tool', columns='Coverage', values='Base Sensitivity')

import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result_Sensitivity, fmt="g", cmap='gist_ncar',center=0,linewidths=.5)
g.set(xlabel='Coverage', ylabel='Tool',  title='Base Sensitivity - Kmer '+str(KMER))

plt.savefig("../figures/ecoli_heatmap_sensitivity_vs_cov_kmer"+str(KMER)+".png", bbox_inches='tight')
