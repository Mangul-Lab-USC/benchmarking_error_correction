# %% [markdown]
# # HIV HAPLOTYPE

# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %%
data = pd.read_csv('../summary_data/haplotype_summary.csv')
print(data.columns)
data["Trim Effeciency"] = data["Base - TP TRIM"]/(data["Base - TP TRIM"] + data["Base - FP TRIM"])
data['total_corrections']=data['Base - TP']+ data['Base - FP']
# Out:
# Index([u'Unnamed: 0', u'EC Filename', u'Wrapper Name', u'Kmer Size',
#        u'Read - TP', u'Read - TN', u'Read - FN', u'Read - FN WRONG',
#        u'Read - FP', u'Read - FP INDEL', u'Total Trimmed Reads',
#        u'Total Reads', u'Base - TP', u'Base - TN', u'Base - FN',
#        u'Base - FN WRONG', u'Base - FP', u'Base - FP INDEL', u'Base - FP TRIM',
#        u'Base - TP TRIM', u'Total Bases', u'Tool', u'Coverage', u'Length',
#        u'Base Sensitivity', u'Base Precision', u'Base Gain', u'Base Accuracy',
#        u'Dataset', u'Trim Percent', u'Trim Effeciency', u'EC', u'Haplotype'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0                              EC Filename Wrapper Name  \
# 0           0  bfc_mix_1_err_rate_1_20.corrected.fastq          bfc
# 1           1  bfc_mix_1_err_rate_1_22.corrected.fastq          bfc
# 2           2  bfc_mix_1_err_rate_1_24.corrected.fastq          bfc
# 3           3  bfc_mix_1_err_rate_1_26.corrected.fastq          bfc
# 4           4  bfc_mix_1_err_rate_1_28.corrected.fastq          bfc
#
#    Kmer Size  Read - TP  Read - TN  Read - FN  Read - FN WRONG  Read - FP  \
# 0         20        112       3207     151655             1059       1443
# 1         22        107       3214     151687             1068       1401
# 2         24        117       3214     151587             1039       1518
# 3         26        111       3210     151552             1009       1594
# 4         28        117       3213     151479             1049       1614
#
#    Read - FP INDEL  ...  Base Sensitivity  Base Precision  Base Gain  \
# 0                5  ...          0.006138        0.870699   0.005227
# 1                4  ...          0.006249        0.875472   0.005360
# 2                6  ...          0.006403        0.869116   0.005439
# 3                5  ...          0.006518        0.865781   0.005507
# 4                9  ...          0.006777        0.867848   0.005745
#
#    Base Accuracy  Dataset  Trim Percent  Trim Effeciency   EC  Haplotype  \
# 0       0.948468      IGH      0.000305         0.999290  bfc          1
# 1       0.948478      IGH      0.000308         0.999295  bfc          1
# 2       0.948481      IGH      0.000308         0.999396  bfc          1
# 3       0.948487      IGH      0.000310         0.999299  bfc          1
# 4       0.948499      IGH      0.000310         0.999299  bfc          1
#
#    total_corrections
# 0              11766
# 1              11913
# 2              12295
# 3              12564
# 4              13029
#
# [5 rows x 34 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
g=sns.set_style("white")
g=sns.set_context("talk")

fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(10,18))
fig.subplots_adjust(hspace=0.8,wspace = 0.4)
fig.suptitle('Gain')

tools=('Bfc','Coral', 'Lighter', 'Musket', 'Reckoner', 'Sga', 'Pollux', 'Bless')
index=0
for ax in axes.flatten():
    g=sns.pointplot(x="Kmer Size", y="Base Gain", hue='Haplotype',  data = data[(data['Tool'] == tools[index])], kind = "point", ax=ax)
    ax.set(title=tools[index])
    
    if index == 1:
        ax.get_legend().set_visible(True)
        ax.legend(bbox_to_anchor=(1, -1.5, 1., .102))
    else:
        ax.get_legend().set_visible(False)
    index+=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
g=sns.set_style("white")
g=sns.set_context("talk")

fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(10,18))
fig.subplots_adjust(hspace=0.8,wspace = 0.5)
fig.suptitle('Number of Correction')

tools=('Bfc','Coral', 'Lighter', 'Musket', 'Reckoner', 'Sga', 'Pollux','Bless')
index=0
for ax in axes.flatten():
    g=sns.pointplot(x="Kmer Size", y="total_corrections", hue='Haplotype',  data = data[(data['Tool'] == tools[index])], kind = "point", ax=ax)
    ax.set(title=tools[index])
    g.set(xlabel='Kmer size', ylabel='Number of Corrections')

    if index == 1:
        ax.get_legend().set_visible(True)
        ax.legend(bbox_to_anchor=(1, -1.5, 1., .102))
    else:
        ax.get_legend().set_visible(False)
    index+=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
g=sns.set_style("white")
g=sns.set_context("talk")

fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(10,18))
fig.subplots_adjust(hspace=0.8,wspace = 0.5)
fig.suptitle('True Positives')

tools=('Bfc','Coral', 'Lighter', 'Musket', 'Reckoner', 'Sga',  'Pollux','Bless')
index=0
for ax in axes.flatten():
    g=sns.pointplot(x="Kmer Size", y="Base - TP", hue='Haplotype',  data = data[(data['Tool'] == tools[index])], kind = "point", ax=ax)
    ax.set(title=tools[index])
    g.set(xlabel='Kmer size', ylabel='True Positives')

    if index == 1:
        ax.get_legend().set_visible(True)
        ax.legend(bbox_to_anchor=(1, -1.5, 1., .102))
    else:
        ax.get_legend().set_visible(False)
    index+=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
g=sns.set_style("white")
g=sns.set_context("talk")

fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(10,18))
fig.subplots_adjust(hspace=0.8,wspace = 0.5)
fig.suptitle('False Negatives')

tools=('Bfc','Coral', 'Lighter', 'Musket', 'Reckoner', 'Sga', 'Pollux','Bless')
index=0
for ax in axes.flatten():
    g=sns.pointplot(x="Kmer Size", y="Base - FN", hue= 'Haplotype',  data = data[(data['Tool'] == tools[index])], kind = "point", ax=ax)
    ax.set(title=tools[index])
    g.set(xlabel='Kmer size', ylabel='False Negatives')

    if index == 1:
        ax.get_legend().set_visible(True)
        ax.legend(bbox_to_anchor=(1, -1.5, 1., .102))
    else:
        ax.get_legend().set_visible(False)
    index+=1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

result =  data[(data['Kmer Size'] == 30) | (data['Kmer Size'] == 9181)]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,15))
fig.subplots_adjust(hspace=0.8,wspace = 0.5)
#fig.suptitle('Gain')

attributes=('Base Gain', 'Base Precision', 'Base Sensitivity', 'Base Accuracy')

index=0
for ax in axes.flatten():   
    result_= result.pivot(index='Tool', columns='Haplotype', values=attributes[index])
    g=sns.heatmap(result_, fmt="g", cmap='gist_ncar',center=0,linewidths=.5, ax=ax)
    g.set(title=attributes[index])
    index+=1

# %%
result_= result.pivot(index='Tool', columns='Haplotype', values='Base Gain')


import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result_, annot=True, cmap='coolwarm',center=0,linewidths=.5,annot_kws={'size':15},fmt=".2f",vmin=-1, vmax=1)

g.set(xlabel='Error rate', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/HIV/gain_haplotypes.png",bbox_inches="tight")
plt.savefig("../figures/HIV/gain_haplotypes.pdf",bbox_inches="tight")
