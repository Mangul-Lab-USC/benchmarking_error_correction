# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %% [markdown]
# # Mix datasets

# %%
data = pd.read_csv('../summary_data/mix_summary.csv')
print(data.columns)
data["Trim Effeciency"] = data["Base - TP TRIM"]/(data["Base - TP TRIM"] + data["Base - FP TRIM"])
data['total_corrections']=data['Base - TP']+ data['Base - FP']
data.head()
# Out:
# Index(['Unnamed: 0', 'EC Filename', 'Wrapper Name', 'Kmer Size', 'Read - TP',
#        'Read - TN', 'Read - FN', 'Read - FN WRONG', 'Read - FP',
#        'Read - FP INDEL', 'Total Trimmed Reads', 'Total Reads', 'Base - TP',
#        'Base - TN', 'Base - FN', 'Base - FN WRONG', 'Base - FP',
#        'Base - FP INDEL', 'Base - FP TRIM', 'Base - TP TRIM', 'Total Bases',
#        'Tool', 'Coverage', 'Length', 'Base Sensitivity', 'Base Precision',
#        'Base Gain', 'Base Accuracy', 'Dataset', 'Trim Percent',
#        'Trim Effeciency', 'Error'],
#       dtype='object')
#    Unnamed: 0                                   EC Filename Wrapper Name  \
# 0           0  bfc_mix_0.0001_err_rate_1_20.corrected.fastq          bfc
# 1           1  bfc_mix_0.0001_err_rate_1_22.corrected.fastq          bfc
# 2           2  bfc_mix_0.0001_err_rate_1_24.corrected.fastq          bfc
# 3           3  bfc_mix_0.0001_err_rate_1_26.corrected.fastq          bfc
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='bfc'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='lighter'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='coral'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='lighter'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='musket'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='reckoner'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='racer'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='fiona'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='sga'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='pollux'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tool='bless'
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Error", y="Base Gain", kind="point",data = data[(data['Wrapper Name'] == tool)]
, hue='Kmer Size')
g.set(xlabel='Error', ylabel='Gain', title=tool)
g.set_xticklabels(rotation=36)
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/mix_gain_tool_"+tool+".png", bbox_inches='tight')
