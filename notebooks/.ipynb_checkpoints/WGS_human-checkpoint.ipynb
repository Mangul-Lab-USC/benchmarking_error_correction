# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %%
data = pd.read_csv('../summary_data/WGS_human.csv')
print(data.columns)
data["Trim Effeciency"] = data["Base - TP TRIM"]/(data["Base - TP TRIM"] + data["Base - FP TRIM"])
data['total_corrections']=data['Base - TP']+ data['Base - FP']
data.head()
# Out:
# Index(['Unnamed: 0', 'EC Filename', 'Wrapper Name', 'Kmer Size', 'Read - TP',
#        'Read - TN', 'Read - FN', 'Read - FN WRONG', 'Read - FP',
#        'Read - FP INDEL', 'Total Trimmed Reads', 'Total Reads', 'Base - TP',
#        'Base - TN', 'Base - FN', 'Base - FN WRONG', 'Base - FP',
#        'Base - FP INDEL', 'Base - FP TRIM', 'Base - TP TRIM', 'Total Bases',
#        'Tool', 'Coverage', 'Length', 'Base Sensitivity', 'Base Precision',
#        'Base Gain', 'Base Accuracy', 'Dataset', 'Trim Percent',
#        'Trim Effeciency'],
#       dtype='object')
#    Unnamed: 0                                     EC Filename Wrapper Name  \
# 0          30  bfc_t1_wgsim_rl__cov_1.1_12.corrected.fastq.gz   run.bfc.sh
# 1          31  bfc_t1_wgsim_rl__cov_1.1_14.corrected.fastq.gz   run.bfc.sh
# 2          37  bfc_t1_wgsim_rl__cov_2.1_16.corrected.fastq.gz   run.bfc.sh
# 3          39  bfc_t1_wgsim_rl__cov_2.1_12.corrected.fastq.gz   run.bfc.sh
# 4          40  bfc_t1_wgsim_rl__cov_1.1_16.corrected.fastq.gz   run.bfc.sh
#
#    Kmer Size  Read - TP  Read - TN  Read - FN  Read - FN WRONG  Read - FP  \
# 0         12        168      24846      16547               38       5101
# 1         14        196      21280      14150               41      11033
# 2         16        261      18808      12274               61      15296
# 3         12        202      21045      13866               70      11517
# 4         16        184      21564      14293               42      10617
#
#    Read - FP INDEL  ...  Coverage  Length  Base Sensitivity  Base Precision  \
# 0                0  ...         1     100          0.038381        0.069400
# 1                0  ...         1     100          0.053077        0.059695
# 2                0  ...         2     100          0.059131        0.055013
# 3                0  ...         2     100          0.039830        0.032307
# 4                0  ...         1     100          0.052879        0.062859
#
#    Base Gain  Base Accuracy  Dataset  Trim Percent  Trim Effeciency  \
# 0  -0.476274       0.992578       T1           0.0              NaN
# 1  -0.782986       0.991041       T1           0.0              NaN
# 2  -0.956580       0.990260       T1           0.0              NaN
# 3  -1.153195       0.989320       T1           0.0              NaN
# 4  -0.735478       0.991274       T1           0.0              NaN
#
#    total_corrections
# 0              12925
# 1              20789
# 2              24903
# 3              28384
# 4              19695
#
# [5 rows x 32 columns]

# %%
data= data[(data['Kmer Size'] ==30) & (data['Tool']!='Lighter')]

# %%
color_dict=dict({'Bfc':'purple','Bless':'orange','Coral':'brown','Fiona':'gray','Lighter':'pink','Musket':'blue','Pollux':'yellow','Racer':'green','Reckoner':'red','Sga':'black'})
print (color_dict)
# Out:
# {'Bfc': 'purple', 'Bless': 'orange', 'Coral': 'brown', 'Fiona': 'gray', 'Lighter': 'pink', 'Musket': 'blue', 'Pollux': 'yellow', 'Racer': 'green', 'Reckoner': 'red', 'Sga': 'black'}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")

g=sns.catplot(x="total_corrections", y="Tool", kind="bar",data= data[(data['Coverage'] ==1)]);
g.set(xlabel='Total number of corrections', ylabel='Methods')
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/total_corrections.pdf", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="total_corrections", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='Total corrections')
g=sns.despine()
#plt.show(g)
plt.savefig("total_corrections_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - TP", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='TP')
g=sns.despine()
#plt.show(g)
plt.savefig("TP_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - FP", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='FP')
g=sns.despine()
#plt.show(g)
plt.savefig("FP_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base - FN", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='FN')
g=sns.despine()
#plt.show(g)
plt.savefig("FN_vs_cov.png", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g = sns.catplot(x="Coverage", y="Base Gain", kind="point",data=data,hue='Tool')
, hue='Tool')
g.set(xlabel='Coverage', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("gain_vs_cov.png", bbox_inches='tight')

# %%
result = data.pivot(index='Tool', columns='Coverage', values='Base Gain')
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result, annot=True, cmap='coolwarm',center=0,linewidths=.5,annot_kws={'size':15},fmt=".2f",vmin=-1, vmax=1)

g.set(xlabel='Coverage', ylabel='Gain')
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/WGS_human/heatmap_humna_gain.png",bbox_inches="tight")
plt.savefig("../figures/WGS_human/heatmap_human_gain.pdf",bbox_inches="tight")

# %%
data=data.fillna(0)
data
# Out:
#      Unnamed: 0                                        EC Filename  \
# 56          141     bfc_t1_wgsim_rl__cov_1.1_30.corrected.fastq.gz
# 62          150     bfc_t1_wgsim_rl__cov_4.1_30.corrected.fastq.gz
# 63          151     bfc_t1_wgsim_rl__cov_2.1_30.corrected.fastq.gz
# 71          159     bfc_t1_wgsim_rl__cov_8.1_30.corrected.fastq.gz
# 88          176    bfc_t1_wgsim_rl__cov_16.1_30.corrected.fastq.gz
# 102         190    bfc_t1_wgsim_rl__cov_32.1_30.corrected.fastq.gz
# 144         232   bless_t1_wgsim_rl__cov_1.1_30.corrected.fastq.gz
# 146         234   bless_t1_wgsim_rl__cov_2.1_30.corrected.fastq.gz
# 147         235   bless_t1_wgsim_rl__cov_4.1_30.corrected.fastq.gz
# 154         242   bless_t1_wgsim_rl__cov_8.1_30.corrected.fastq.gz
# 173         266  bless_t1_wgsim_rl__cov_16.1_30.corrected.fastq.gz
# 218         321   coral_t1_wgsim_rl__cov_1.1_30.corrected.fastq.gz
# 219         322  bless_t1_wgsim_rl__cov_32.1_30.corrected.fastq.gz
# 223         327   coral_t1_wgsim_rl__cov_2.1_30.corrected.fastq.gz
# 229         337   coral_t1_wgsim_rl__cov_4.1_30.corrected.fastq.gz
# 233         346   coral_t1_wgsim_rl__cov_8.1_30.corrected.fastq.gz
# 255         372  coral_t1_wgsim_rl__cov_16.1_30.corrected.fastq.gz
# 266         392  coral_t1_wgsim_rl__cov_32.1_30.corrected.fastq.gz
# 387        1002  musket_t1_wgsim_rl__cov_1.1_30.corrected.fastq.gz
# 390        1005  musket_t1_wgsim_rl__cov_2.1_30.corrected.fastq.gz
# 392        1007  musket_t1_wgsim_rl__cov_4.1_30.corrected.fastq.gz
# 400        1015  musket_t1_wgsim_rl__cov_8.1_30.corrected.fastq.gz
# 417        1032  musket_t1_wgsim_rl__cov_16.1_30.corrected.fast...
# 436        1051  musket_t1_wgsim_rl__cov_32.1_30.corrected.fast...
# 445        1060  pollux_t1_wgsim_rl__cov_1.1_30.corrected.fastq.gz
# 453        1068  pollux_t1_wgsim_rl__cov_2.1_30.corrected.fastq.gz
# 458        1073  pollux_t1_wgsim_rl__cov_4.1_30.corrected.fastq.gz
# 466        1081  pollux_t1_wgsim_rl__cov_8.1_30.corrected.fastq.gz
# 477        1092  pollux_t1_wgsim_rl__cov_16.1_30.corrected.fast...
# 517        1132  pollux_t1_wgsim_rl__cov_32.1_30.corrected.fast...
# 535        1150  reckoner_t1_wgsim_rl__cov_1.1_30.corrected.fas...
# 540        1155  reckoner_t1_wgsim_rl__cov_2.1_30.corrected.fas...
# 550        1165  reckoner_t1_wgsim_rl__cov_4.1_30.corrected.fas...
# 551        1166  reckoner_t1_wgsim_rl__cov_8.1_30.corrected.fas...
# 577        1192  reckoner_t1_wgsim_rl__cov_16.1_30.corrected.fa...
# 608        1223     sga_t1_wgsim_rl__cov_1.1_30.corrected.fastq.gz
# 616        1231     sga_t1_wgsim_rl__cov_2.1_30.corrected.fastq.gz
# 623        1238  reckoner_t1_wgsim_rl__cov_32.1_30.corrected.fa...
# 625        1240     sga_t1_wgsim_rl__cov_4.1_30.corrected.fastq.gz
# 631        1246     sga_t1_wgsim_rl__cov_8.1_30.corrected.fastq.gz
# 637        1252    sga_t1_wgsim_rl__cov_16.1_30.corrected.fastq.gz
# 651        1266    sga_t1_wgsim_rl__cov_32.1_30.corrected.fastq.gz
#
#         Wrapper Name  Kmer Size  Read - TP  Read - TN  Read - FN  \
# 56        run.bfc.sh         30         92      26553      17667
# 62        run.bfc.sh         30        380      26373      16903
# 63        run.bfc.sh         30        137      26471      17325
# 71        run.bfc.sh         30       1034      26232      16152
# 88        run.bfc.sh         30       3182      26355      13993
# 102       run.bfc.sh         30       8363      27002       8962
# 144     run.bless.sh         30         11      32364      13638
# 146     run.bless.sh         30         16      32353      13709
# 147     run.bless.sh         30         37      32252      13277
# 154     run.bless.sh         30         68      31690      13188
# 173     run.bless.sh         30         73      31474      13151
# 218     run.coral.sh         30        119      27908      18362
# 219     run.bless.sh         30      14931      30308       1132
# 223     run.coral.sh         30        429      27963      17808
# 229     run.coral.sh         30       1471      28020      16635
# 233     run.coral.sh         30       4667      27788      13318
# 255     run.coral.sh         30      11206      27451       6618
# 266     run.coral.sh         30      16044      27313       1567
# 387    run.musket.sh         30         33      26480      17645
# 390    run.musket.sh         30         31      26090      17243
# 392    run.musket.sh         30         50      25968      17000
# 400    run.musket.sh         30         56      25622      16822
# 417    run.musket.sh         30        101      25096      16488
# 436    run.musket.sh         30      15975      27945       1695
# 445    run.pollux.sh         30         93       8681       4535
# 453    run.pollux.sh         30        334      25532      12843
# 458    run.pollux.sh         30        666      26059      13321
# 466    run.pollux.sh         30       1539      26030      13474
# 477    run.pollux.sh         30       4483      25453      11387
# 517    run.pollux.sh         30      10947      25581       5221
# 535  run.reckoner.sh         30         33      27324      18109
# 540  run.reckoner.sh         30         59      27241      17769
# 550  run.reckoner.sh         30        161      27245      17548
# 551  run.reckoner.sh         30        388      27189      17274
# 577  run.reckoner.sh         30       1372      27158      16289
# 608       run.sga.sh         30         53      27606      18296
# 616       run.sga.sh         30        142      27636      17991
# 623  run.reckoner.sh         30      15137      28228       2893
# 625       run.sga.sh         30        503      27654      17472
# 631       run.sga.sh         30       1683      27539      16178
# 637       run.sga.sh         30       6240      27578      11641
# 651       run.sga.sh         30      14365      28077       3578
#
#      Read - FN WRONG  Read - FP  Read - FP INDEL  ...  Coverage  Length  \
# 56                 4       2384                0  ...         1     100
# 62                 5       3039                0  ...         4     100
# 63                 4       2763                0  ...         2     100
# 71                10       3272                0  ...         8     100
# 88                23       3147                0  ...        16     100
# 102               34       2339                0  ...        32     100
# 144                0        628               59  ...         1     100
# 146                0        588               34  ...         2     100
# 147                1       1042               91  ...         4     100
# 154                1       1564              189  ...         8     100
# 173                2       1782              218  ...        16     100
# 218                0        276               35  ...         1     100
# 219                4        313               12  ...        32     100
# 223                2        436               62  ...         2     100
# 229                3        505               66  ...         4     100
# 233                1        774              152  ...         8     100
# 255                7       1170              248  ...        16     100
# 266                9       1406              361  ...        32     100
# 387                5       2528                9  ...         1     100
# 390                1       3327                8  ...         2     100
# 392                1       3673                8  ...         4     100
# 400                2       4189                9  ...         8     100
# 417                7       5000                8  ...        16     100
# 436               20       1064                1  ...        32     100
# 445                6       2109             1172  ...         1     100
# 453               15       5058             2918  ...         2     100
# 458               13       4018             2623  ...         4     100
# 466               14       3192             2451  ...         8     100
# 477               22       2975             2380  ...        16     100
# 517               42       2740             2169  ...        32     100
# 535                1       1041              192  ...         1     100
# 540                3       1381              247  ...         2     100
# 550                3       1506              237  ...         4     100
# 551                1       1585              263  ...         8     100
# 577                8       1546              327  ...        16     100
# 608                2        735                8  ...         1     100
# 616                1        914               16  ...         2     100
# 623               14        351               77  ...        32     100
# 625                2       1055               14  ...         4     100
# 631                7       1272               21  ...         8     100
# 637               11       1194               36  ...        16     100
# 651                5        667                8  ...        32     100
#
#      Base Sensitivity  Base Precision  Base Gain  Base Accuracy  Dataset  \
# 56           0.023911        0.089733  -0.218644       0.993861       T1
# 62           0.049382        0.139048  -0.256378       0.993766       T1
# 63           0.031049        0.096969  -0.258095       0.993718       T1
# 71           0.092374        0.233388  -0.211049       0.994002       T1
# 88           0.221893        0.469227  -0.029105       0.994851       T1
# 102          0.514669        0.779409   0.369006       0.996831       T1
# 144          0.007925        0.040574  -0.179468       0.699635       T1
# 146          0.006908        0.038331  -0.166402       0.699522       T1
# 147          0.016494        0.049250  -0.301916       0.701404       T1
# 154          0.031846        0.060766  -0.460391       0.702851       T1
# 173          0.034859        0.062638  -0.486805       0.703837       T1
# 218          0.010753        0.275599  -0.017511       0.994873       T1
# 219          0.930172        0.960413   0.891831       0.973345       T1
# 223          0.033103        0.423014  -0.012049       0.994945       T1
# 229          0.096307        0.671682   0.049232       0.995280       T1
# 233          0.283793        0.788254   0.207559       0.996073       T1
# 255          0.652036        0.858778   0.544812       0.997719       T1
# 266          0.916150        0.882511   0.794182       0.998964       T1
# 387          0.025597        0.055767  -0.407811       0.992909       T1
# 390          0.036677        0.056244  -0.578750       0.992122       T1
# 392          0.043014        0.058207  -0.652949       0.991803       T1
# 400          0.051206        0.062994  -0.710467       0.991538       T1
# 417          0.066214        0.068205  -0.838378       0.990819       T1
# 436          0.911111        0.919457   0.831300       0.999146       T1
# 445          0.113235        0.060052  -1.659137       0.988895       T1
# 453          0.107028        0.062141  -1.508277       0.989640       T1
# 458          0.113249        0.079525  -1.197582       0.990626       T1
# 466          0.154655        0.125228  -0.925673       0.991373       T1
# 477          0.322915        0.249974  -0.645964       0.992061       T1
# 517          0.680509        0.430546  -0.219555       0.993893       T1
# 535          0.012896        0.049109  -0.236816       0.993711       T1
# 540          0.021984        0.063705  -0.301116       0.993421       T1
# 550          0.028568        0.076682  -0.315412       0.993399       T1
# 551          0.043793        0.110419  -0.309018       0.993437       T1
# 577          0.101108        0.187321  -0.337541       0.993218       T1
# 608          0.013184        0.117335  -0.085995       0.994528       T1
# 616          0.020075        0.147309  -0.096131       0.994523       T1
# 623          0.837450        0.880814   0.724132       0.998592       T1
# 625          0.041154        0.249607  -0.082567       0.994624       T1
# 631          0.107143        0.423149  -0.038918       0.994849       T1
# 637          0.346243        0.738824   0.223845       0.996108       T1
# 651          0.788411        0.939561   0.737695       0.998682       T1
#
#      Trim Percent  Trim Effeciency  total_corrections
# 56   0.000000e+00         0.000000               6263
# 62   0.000000e+00         0.000000               8213
# 63   0.000000e+00         0.000000               7456
# 71   0.000000e+00         0.000000               9135
# 88   0.000000e+00         0.000000              11016
# 102  0.000000e+00         0.000000              15395
# 144  2.972853e-01         0.005126               2856
# 146  2.974294e-01         0.005003               2726
# 147  2.951524e-01         0.005105               4935
# 154  2.930677e-01         0.004970               7122
# 173  2.920264e-01         0.005155               7500
# 218  0.000000e+00         0.000000                870
# 219  2.676135e-02         0.022484              19865
# 223  8.565193e-07         0.250000               1737
# 229  2.141294e-07         0.000000               3220
# 233  1.070624e-06         0.400000               8115
# 255  1.498835e-06         0.142857              17389
# 266  1.498792e-06         0.285714              23783
# 387  2.141322e-06         0.000000              10763
# 390  6.423970e-07         0.000000              15151
# 392  6.423972e-07         0.000000              17064
# 400  8.565294e-07         0.000000              18718
# 417  1.284794e-06         0.000000              22565
# 436  2.141327e-07         0.000000              23142
# 445  1.263541e-05         0.000000               9640
# 453  1.817565e-05         0.011765              24065
# 458  1.326041e-05         0.016129              20365
# 466  1.647033e-05         0.012987              18427
# 477  2.310117e-05         0.009259              21605
# 517  2.545488e-05         0.025210              29504
# 535  6.059116e-05         0.003534               5158
# 540  8.478270e-05         0.005051               6910
# 550  7.493363e-05         0.000000               7374
# 551  8.371012e-05         0.010230               7789
# 577  9.719061e-05         0.004405              10564
# 608  6.423968e-07         0.000000               2623
# 616  2.783712e-06         0.000000               3144
# 623  1.905629e-05         0.000000              21559
# 625  2.141318e-06         0.000000               3788
# 631  3.426098e-06         0.000000               5795
# 637  6.852150e-06         0.000000              10839
# 651  1.070660e-06         0.000000              19597
#
# [42 rows x 32 columns]

# %%
result = data.pivot(index='Tool', columns='Coverage', values='Base Precision')

import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result, annot=True, cmap='coolwarm',center=0,linewidths=.5,annot_kws={'size':15},fmt=".2f",vmin=0, vmax=1)

g.set(xlabel='Coverage', ylabel='Precision')
g=sns.despine()
#plt.show(g)

plt.savefig("../figures/WGS_human/heatmap_humna_precision.png",bbox_inches="tight")
plt.savefig("../figures/WGS_human/heatmap_human_precision.pdf",bbox_inches="tight")

# %%
result = data.pivot(index='Tool', columns='Coverage', values='Base Sensitivity')

import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.heatmap(result, annot=True, cmap='coolwarm',center=0,linewidths=.5,annot_kws={'size':15},fmt=".2f",vmin=0, vmax=1)

g.set(xlabel='Coverage', ylabel='Sensitivity')
g=sns.despine()
#plt.show(g)
plt.savefig("../figures/WGS_human/heatmap_humna_sensitivity.png",bbox_inches="tight")
plt.savefig("../figures/WGS_human/heatmap_human_sensitivity.pdf",bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 32)] , x='Base - TP', y='Base - FP', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 200})
g.set(xlabel='TP', ylabel='FP')

#plt.title(str(th)+"bp")
#g.set(xscale="log")
#g.set(yscale="log")
plt.ylim(0, 15000)
plt.xlim(0, 24000)

#g=plt.title("", fontsize=30)
g=sns.despine()
plt.savefig("../figures/WGS_human//lmplot_TP_vs_FP.png")
plt.savefig("../figures/WGS_human//lmplot_TP_vs_FP.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 32)] , x='Base - FP', y='Base - FN', hue='Tool', palette=color_dict,fit_reg=False,aspect=1.3,scatter_kws={"s": 200})
g.set(xlabel='FP', ylabel='FN')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
#g.set(xscale="log")
#g.set(yscale="log")
plt.ylim(0, 15000)
plt.xlim(0, 24000)
#g=plt.title("", fontsize=30)
g=sns.despine()
plt.savefig("../figures/WGS_human//lmplot_FP_vs_FN.png")
plt.savefig("../figures/WGS_human//lmplot_FP_vs_FN.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 32)] , x='Base Precision', y='Base Sensitivity', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 200})
g.set(xlabel='Precision', ylabel='Sensitivity')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human//lmplot_Precision_vs_Sensitivity.png")
plt.savefig("../figures/WGS_human//lmplot_Precision_vs_Sensitivity.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 32)] , y='Trim Effeciency', x='Trim Percent', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 150})
g.set(ylabel='Trim Efficiency', xlabel='Trim Percent')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
g=plt.title("Coverage 32x", fontsize=25)

plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov32.png")
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov32.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 16)] , y='Trim Effeciency', x='Trim Percent', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 150})
g.set(ylabel='Trim Efficiency', xlabel='Trim Percent')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
g=plt.title("Coverage 16x", fontsize=25)

plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov16.png")
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov16.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 8)] , y='Trim Effeciency', x='Trim Percent', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 150})
g.set(ylabel='Trim Efficiency', xlabel='Trim Percent')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
g=plt.title("Coverage 8x", fontsize=25)

plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov8.png")
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov8.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 4)] , y='Trim Effeciency', x='Trim Percent', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 150})
g.set(ylabel='Trim Efficiency', xlabel='Trim Percent')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
g=plt.title("Coverage 4x", fontsize=25)

plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov4.png")
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov4.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 2)] , y='Trim Effeciency', x='Trim Percent', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 150})
g.set(ylabel='Trim Efficiency', xlabel='Trim Percent')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
g=plt.title("Coverage 2x", fontsize=25)

plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov2.png")
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov2.pdf")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g=sns.set_style("white")
g=sns.set_context("talk")
g=sns.lmplot(data=data[(data['Coverage'] == 1)] , y='Trim Effeciency', x='Trim Percent', hue='Tool', palette=color_dict, fit_reg=False,aspect=1.3,scatter_kws={"s": 150})
g.set(ylabel='Trim Efficiency', xlabel='Trim Percent')
#plt.title(str(th)+"bp")
#g.set(xscale="log");
g=plt.title("Coverage 1x", fontsize=25)

plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
g=sns.despine()
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov1.png")
plt.savefig("../figures/WGS_human/lmplot_trimefficiency_vs_trimpercent_cov1.pdf")

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'EC Filename', 'Wrapper Name', 'Kmer Size', 'Read - TP',
#        'Read - TN', 'Read - FN', 'Read - FN WRONG', 'Read - FP',
#        'Read - FP INDEL', 'Total Trimmed Reads', 'Total Reads', 'Base - TP',
#        'Base - TN', 'Base - FN', 'Base - FN WRONG', 'Base - FP',
#        'Base - FP INDEL', 'Base - FP TRIM', 'Base - TP TRIM', 'Total Bases',
#        'Tool', 'Coverage', 'Length', 'Base Sensitivity', 'Base Precision',
#        'Base Gain', 'Base Accuracy', 'Dataset', 'Trim Percent',
#        'Trim Effeciency', 'total_corrections'],
#       dtype='object')
