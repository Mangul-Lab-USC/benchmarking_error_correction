# %% [markdown]
# # Dataset D3

# %% [markdown]
# ## Importing libraries

# %%
from __future__ import division
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import math
import seaborn as sns
import os

# %% [markdown]
# ## Data reading and formating

# %%
data = pd.read_csv('../summary_data/D3_TCRA_simulated.csv')
data['total_corrections']=data['Base - TP']+ data['Base - FP']

# %% [markdown]
# ## Defining color dictionary

# %%
color_dict=dict({'Bfc':'purple','Bless':'orange','Coral':'brown','Fiona':'gray','Lighter':'pink','Musket':'blue','Pollux':'yellow','Racer':'green','Reckoner':'red','Sga':'black'})

# %% [markdown]
# ## Selecting best kmer for each tool

# %%
data_best = data.loc[data.groupby(["Tool", "Coverage"])["Base Gain"].idxmax()]  
data_best = data_best.fillna(0)

# %% [markdown]
# <br>
# <br>
#
# # Figure S12a
# The effect of kmer size on the accuracy of the error correction tools across for TCR-Seq data for coverage of 1x. <br> The reads were simulated from TCRA transcripts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("poster")

g=sns.barplot(x="Kmer Size", 
              y="Base Gain",
              data = data[(data['Coverage'] ==1) & (data['Tool'] !='Fiona') & (data['Tool'] !='Racer')],
              hue='Tool', 
              palette=color_dict)

g.set(xlabel='Kmer size', ylabel='Gain')
plt.ylim( 0, 1)
plt.title("Coverage 1x", fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
fig = plt.gcf()
fig.set_size_inches(16, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS12a_gain_vs_kmer_cov1.png", bbox_inches='tight')
plt.savefig("../figures/D3_TCRA_simulated/FigS12a_gain_vs_kmer_cov1.pdf", bbox_inches='tight')

# %% [markdown]
# <br>
# <br>
#
# # Figure S12b
# The effect of kmer size on the accuracy of the error correction tools across for TCR-Seq data for coverage of 2x.
# <br> The reads were simulated from TCRA transcripts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("poster")

g=sns.barplot(x="Kmer Size", 
              y="Base Gain",
              data = data[(data['Coverage'] == 2) & (data['Tool'] !='Fiona') & (data['Tool'] !='Racer')],
              hue='Tool', 
              palette=color_dict)

g.set(xlabel='Kmer size', ylabel='Gain')
plt.ylim( 0, 1)
plt.title("Coverage 2x", fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
fig = plt.gcf()
fig.set_size_inches(16, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS12b_gain_vs_kmer_cov2.png", bbox_inches='tight')
plt.savefig("../figures/D3_TCRA_simulated/FigS12b_gain_vs_kmer_cov2.pdf", bbox_inches='tight')

# %% [markdown]
# <br>
# <br>
#
# # Figure S12c
# The effect of kmer size on the accuracy of the error correction tools across for TCR-Seq data for coverage of 4x. <br>
# The reads were simulated from TCRA transcripts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("poster")

g=sns.barplot(x="Kmer Size", 
              y="Base Gain",
              data = data[(data['Coverage'] == 4) & (data['Tool'] !='Fiona') & (data['Tool'] !='Racer')],
              hue='Tool', 
              palette=color_dict)

g.set(xlabel='Kmer size', ylabel='Gain')
plt.ylim( 0, 1)
plt.title("Coverage 4x", fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
fig = plt.gcf()
fig.set_size_inches(16, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS12c_gain_vs_kmer_cov4.png", bbox_inches='tight')
plt.savefig("../figures/D3_TCRA_simulated/FigS12c_gain_vs_kmer_cov4.pdf", bbox_inches='tight')

# %% [markdown]
# <br>
# <br>
#
# # Figure S12d
# The effect of kmer size on the accuracy of the error correction tools across for TCR-Seq data for coverage of 8x. <br> The reads were simulated from TCRA transcripts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("poster")

g=sns.barplot(x="Kmer Size", 
              y="Base Gain",
              data = data[(data['Coverage'] == 8) & (data['Tool'] !='Fiona') & (data['Tool'] !='Racer')],
              hue='Tool', 
              palette=color_dict)

g.set(xlabel='Kmer size', ylabel='Gain')
plt.ylim( 0, 1)
plt.title("Coverage 8x", fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
fig = plt.gcf()
fig.set_size_inches(16, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS12d_gain_vs_kmer_cov8.png", bbox_inches='tight')
plt.savefig("../figures/D3_TCRA_simulated/FigS12d_gain_vs_kmer_cov8.pdf", bbox_inches='tight')

# %% [markdown]
# <br>
# <br>
#
# # Figure S12e
# The effect of kmer size on the accuracy of the error correction tools across for TCR-Seq data for coverage of 16x. <br> The reads were simulated from TCRA transcripts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("poster")

g=sns.barplot(x="Kmer Size", 
              y="Base Gain",
              data = data[(data['Coverage'] == 16) & (data['Tool'] !='Fiona') & (data['Tool'] !='Racer')],
              hue='Tool', 
              palette=color_dict)

g.set(xlabel='Kmer size', ylabel='Gain')
plt.ylim( 0, 1)
plt.title("Coverage 16x", fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
fig = plt.gcf()
fig.set_size_inches(16, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS12e_gain_vs_kmer_cov16.png", bbox_inches='tight')
plt.savefig("../figures/D3_TCRA_simulated/FigS12e_gain_vs_kmer_cov16.pdf", bbox_inches='tight')

# %% [markdown]
# <br>
# <br>
#
# # Figure S12f
# The effect of kmer size on the accuracy of the error correction tools across for TCR-Seq data for coverage of 32x. <br> The reads were simulated from TCRA transcripts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("poster")

g=sns.barplot(x="Kmer Size", 
              y="Base Gain",
              data = data[(data['Coverage'] == 32) & (data['Tool'] !='Fiona') & (data['Tool'] !='Racer')],
              hue='Tool', 
              palette=color_dict)

g.set(xlabel='Kmer size', ylabel='Gain')
plt.ylim( 0, 1)
plt.title("Coverage 32x", fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.despine()
fig = plt.gcf()
fig.set_size_inches(16, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS12f_gain_vs_kmer_cov32.png", bbox_inches='tight')
plt.savefig("../figures/D3_TCRA_simulated/FigS12f_gain_vs_kmer_cov32.pdf", bbox_inches='tight')

# %% [markdown]
#  <br>
# <br>
#
# # Figure S14
# Heatmap depicting the precision across various coverage settings of TCR-seq.
# <br>Each row corresponds to an error correction tool, and each column corresponds to a dataset with a given coverage.
# <br> For each tool, the best k-mer size was selected.

# %%
result = data_best.pivot(index='Tool', columns='Coverage', values='Base Gain')\
    .sort_values(by="Tool", ascending=False)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

fig, ax = plt.subplots(figsize=(8,5))
g=sns.heatmap(result, 
              annot=True, 
              cmap='coolwarm',
              center=0,
              linewidths=.5,
              annot_kws={'size':15},
              fmt=".2f",
              vmin=-1, 
              vmax=1)

g.set(xlabel='Coverage', ylabel='Gain')
g.set_ylim(0, 10)
g=sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS14_heatmap_humna_gain.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS14_heatmap_human_gain.pdf",bbox_inches="tight")

# %% [markdown]
#  <br>
# <br>
#
# # Figure S15
# Heatmap depicting the gain across various coverage settings of TCR-seq.
# <br>Each row corresponds to an error correction tool, and each column corresponds to a dataset with a given coverage.
# <br> For each tool, the best k-mer size was selected.

# %%
result = data_best.pivot(index='Tool', columns='Coverage', values='Base Precision')\
    .sort_values(by="Tool", ascending=False)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")
g=sns.heatmap(result, 
              annot=True, 
              cmap='coolwarm',
              center=0,
              linewidths=.5,
              annot_kws={'size':15},
              fmt=".2f",
              vmin=-1, 
              vmax=1)

g.set(xlabel='Coverage', ylabel='Precision')
sns.despine()
g.set_ylim(0, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS15_heatmap_human_precision.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS15_heatmap_human_precision.pdf",bbox_inches="tight")

# %% [markdown]
#  <br>
# <br>
#
# # Figure S16
# Heatmap depicting the sensitivity across various coverage settings of TCR-seq.<br>
# Each row corresponds to an error correction tool, and each column corresponds to a dataset with a given coverage.
# <br> For each tool, the best k-mer size was selected.

# %%
result = data_best.pivot(index='Tool', columns='Coverage', values='Base Sensitivity')\
    .sort_values(by="Tool", ascending=False)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")
g=sns.heatmap(result, 
              annot=True, 
              cmap='coolwarm',
              center=0,
              linewidths=.5,
              annot_kws={'size':15},
              fmt=".2f",
              vmin=-1, 
              vmax=1)

g.set(xlabel='Coverage', ylabel='Sensitivity')
sns.despine()
g.set_ylim(0, 10)

plt.savefig("../figures/D3_TCRA_simulated/FigS16_heatmap_human_sensitivity.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS16_heatmap_human_sensitivity.pdf",bbox_inches="tight")

# %% [markdown]
# <br>
# <br>
#
# # Figure S17a
# Trimming Efficiency vs. Trim Proportion for TCR-Seq simulated data for coverafe 1x.
# <br>The reads were simulated from TCRA transcripts
# <br> For each tool, the best k-mer size was selected.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

g=sns.lmplot(data=data_best[(data_best['Coverage'] == 1)] , 
             x='Trim Percent', 
             y='Trim Efficiency', 
             hue='Tool', 
             palette=color_dict, 
             fit_reg=False,
             aspect=1.3,
             scatter_kws={"s": 150})

g.set(xlabel='Trim Percent', ylabel='Trim Efficiency')
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
plt.title("Coverage 1x", fontsize=20)
sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS17a_efficiency_vs_percent_cov1.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS17a_efficiency_vs_percent_cov1.pdf",bbox_inches="tight")

# %% [markdown]
# <br>
# <br>
#
# # Figure S17b
# Trimming Efficiency vs. Trim Proportion for TCR-Seq simulated data for coverafe 2x.
# <br>The reads were simulated from TCRA transcripts
# <br> For each tool, the best k-mer size was selected.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

g=sns.lmplot(data=data_best[(data_best['Coverage'] == 2)] , 
             x='Trim Percent', 
             y='Trim Efficiency', 
             hue='Tool', 
             palette=color_dict, 
             fit_reg=False,
             aspect=1.3,
             scatter_kws={"s": 150})

g.set(xlabel='Trim Percent', ylabel='Trim Efficiency')
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
plt.title("Coverage 2x", fontsize=20)
sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS17b_efficiency_vs_percent_cov2.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS17b_efficiency_vs_percent_cov2.pdf",bbox_inches="tight")

# %% [markdown]
# <br>
# <br>
#
# # Figure S17c
# Trimming Efficiency vs. Trim Proportion for TCR-Seq simulated data for coverafe 4x.
# <br>The reads were simulated from TCRA transcripts.
# <br> For each tool, the best k-mer size was selected.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

g=sns.lmplot(data=data_best[(data_best['Coverage'] == 4)] , 
             x='Trim Percent', 
             y='Trim Efficiency', 
             hue='Tool', 
             palette=color_dict, 
             fit_reg=False,
             aspect=1.3,
             scatter_kws={"s": 150})

g.set(xlabel='Trim Percent', ylabel='Trim Efficiency')
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
plt.title("Coverage 4x", fontsize=20)
sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS17c_efficiency_vs_percent_cov4.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS17c_efficiency_vs_percent_cov4.pdf",bbox_inches="tight")

# %% [markdown]
# <br>
# <br>
#
# # Figure S17d
# Trimming Efficiency vs. Trim Proportion for TCR-Seq simulated data for coverafe 8x.
# <br>The reads were simulated from TCRA transcripts.
# <br> For each tool, the best k-mer size was selected.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

g=sns.lmplot(data=data_best[(data_best['Coverage'] == 8)] , 
             x='Trim Percent', 
             y='Trim Efficiency', 
             hue='Tool', 
             palette=color_dict, 
             fit_reg=False,
             aspect=1.3,
             scatter_kws={"s": 150})

g.set(xlabel='Trim Percent', ylabel='Trim Efficiency')
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
plt.title("Coverage 8x", fontsize=20)
sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS17d_efficiency_vs_percent_cov8.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS17d_efficiency_vs_percent_cov8.pdf",bbox_inches="tight")

# %% [markdown]
# <br>
# <br>
#
# # Figure S17e
# Trimming Efficiency vs. Trim Proportion for TCR-Seq simulated data for coverafe 16x.
# <br>The reads were simulated from TCRA transcripts.
# <br> For each tool, the best k-mer size was selected.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

g=sns.lmplot(data=data_best[(data_best['Coverage'] == 16)] , 
             x='Trim Percent', 
             y='Trim Efficiency', 
             hue='Tool', 
             palette=color_dict, 
             fit_reg=False,
             aspect=1.3,
             scatter_kws={"s": 150})

g.set(xlabel='Trim Percent', ylabel='Trim Efficiency')
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
plt.title("Coverage 16x", fontsize=20)
sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS17e_efficiency_vs_percent_cov16.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS17e_efficiency_vs_percent_cov16.pdf",bbox_inches="tight")

# %% [markdown]
# <br>
# <br>
#
# # Figure S17f
# Trimming Efficiency vs. Trim Proportion for TCR-Seq simulated data for coverafe 32x.
# <br>The reads were simulated from TCRA transcripts.
# <br> For each tool, the best k-mer size was selected.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk")

g=sns.lmplot(data=data_best[(data_best['Coverage'] == 32)] , 
             x='Trim Percent', 
             y='Trim Efficiency', 
             hue='Tool', 
             palette=color_dict, 
             fit_reg=False,
             aspect=1.3,
             scatter_kws={"s": 150})

g.set(xlabel='Trim Percent', ylabel='Trim Efficiency')
plt.ylim(-0.1, 1.1)
plt.xlim(-0.1, 1.1)
plt.title("Coverage 32x", fontsize=20)
sns.despine()

plt.savefig("../figures/D3_TCRA_simulated/FigS17f_efficiency_vs_percent_cov32.png",bbox_inches="tight")
plt.savefig("../figures/D3_TCRA_simulated/FigS17f_efficiency_vs_percent_cov32.pdf",bbox_inches="tight")
